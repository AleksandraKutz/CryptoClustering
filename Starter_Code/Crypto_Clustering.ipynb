# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %%
df_market_data.dtypes
# Out:
# price_change_percentage_24h     float64
# price_change_percentage_7d      float64
# price_change_percentage_14d     float64
# price_change_percentage_30d     float64
# price_change_percentage_60d     float64
# price_change_percentage_200d    float64
# price_change_percentage_1y      float64
# dtype: object

# %%
df_market_data.columns
# Out:
# Index(['price_change_percentage_24h', 'price_change_percentage_7d',
#        'price_change_percentage_14d', 'price_change_percentage_30d',
#        'price_change_percentage_60d', 'price_change_percentage_200d',
#        'price_change_percentage_1y'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
Scaled_market = StandardScaler().fit_transform(df_market_data[['price_change_percentage_24h', 'price_change_percentage_7d',
       'price_change_percentage_14d', 'price_change_percentage_30d',
       'price_change_percentage_60d', 'price_change_percentage_200d',
       'price_change_percentage_1y']])

print(Scaled_market[:5])
# Out:
# [[ 0.50852937  0.49319307  0.77220043  0.23545963 -0.0674951  -0.35595348
#   -0.25163688]
#  [ 0.18544589  0.93444504  0.55869212 -0.05434093 -0.27348273 -0.11575947
#   -0.19935211]
#  [ 0.02177396 -0.70633685 -0.02168042 -0.06103015  0.00800452 -0.55024692
#   -0.28206051]
#  [-0.04076438 -0.81092807  0.24945797 -0.05038797 -0.37316402 -0.45825882
#   -0.29554614]
#  [ 1.19303608  2.00095907  1.76061001  0.54584206 -0.29120287 -0.49984776
#   -0.27031695]]

# %%
# Create a DataFrame with the scaled data

scaled_df = pd.DataFrame(Scaled_market, columns = ['price_change_percentage_24h', 'price_change_percentage_7d',
       'price_change_percentage_14d', 'price_change_percentage_30d',
       'price_change_percentage_60d', 'price_change_percentage_200d',
       'price_change_percentage_1y'])

# Copy the crypto names from the original DataFrame

scaled_df['coin_id'] = df_market_data.index

# Set the coin_id column as index

scaled_df.set_index('coin_id', inplace = True)

# Display the scaled DataFrame

scaled_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values from 1 to 11


k = list(range(1,11))

# %%
# Create an empty list to store the inertia values
iner_list = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_scaled`
# 3. Append the model.inertia_ to the inertia list

for i in k:
    model = KMeans(n_clusters = i, random_state= 1)
    model.fit(scaled_df)
    iner_list.append(model.inertia_)
    
iner_list
# Out:
# [287.0,
#  212.1233420748626,
#  165.1367523344681,
#  79.02243535120975,
#  66.41305075939437,
#  61.634088110682214,
#  46.074467441030215,
#  43.39269411734827,
#  32.913222659715245,
#  30.469111293270355]

# %%
# Create a dictionary with the data to plot the Elbow curve

elbow_dict = {
    "k": k,
    "inertia": iner_list
}

# Create a DataFrame with the data to plot the Elbow curve

elbow_df = pd.DataFrame(elbow_dict)
elbow_df
# Out:
#     k     inertia
# 0   1  287.000000
# 1   2  212.123342
# 2   3  165.136752
# 3   4   79.022435
# 4   5   66.413051
# 5   6   61.634088
# 6   7   46.074467
# 7   8   43.392694
# 8   9   32.913223
# 9  10   30.469111

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.

elbow_df.hvplot.line(
    x= "k",
    y= "inertia")
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** The best value for "k" is 4.

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled DataFrame

# %%
# Initialize the K-Means model using the best value for k

kmodel = KMeans(n_clusters=4, random_state = 1)

# %%
# Fit the K-Means model using the scaled DataFrame
kmodel.fit(scaled_df)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled DataFrame

predi = kmodel.predict(scaled_df)

# Print the resulting array of cluster values.

predi
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 3, 2, 0, 0, 1, 0, 0, 0, 0],
#       dtype=int32)

# %%
# Create a copy of the scaled DataFrame

scaled_df_2 = scaled_df.copy()

# %%
# Add a new column to the copy of the scaled DataFrame with the predicted clusters

scaled_df_2['clusters'] = predi

# Display the copy of the scaled DataFrame
scaled_df_2.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using hvPlot by setting
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.

scaled_df_2.hvplot.scatter(
x = "price_change_percentage_24h",
y = "price_change_percentage_7d",
by = "clusters",
hover_cols="coin_id",
title = "Cryptocurrency Price Changes",
xlabel = "24h Price Change (%)",
ylabel = "7d Price Change (%)")
# Out:
# :NdOverlay   [clusters]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce the original scaled DataFrame
# down to three principal components.

scaled_pca = pca.fit_transform(scaled_df)

# View the scaled PCA data

scaled_pca[:5]
# Out:
# array([[-0.60066733,  0.84276006,  0.46159457],
#        [-0.45826071,  0.45846566,  0.95287678],
#        [-0.43306981, -0.16812638, -0.64175193],
#        [-0.47183495, -0.22266008, -0.47905316],
#        [-1.15779997,  2.04120919,  1.85971527]])

# %%
# Retrieve the explained variance to determine how much information
# can be attributed to each principal component.

pca.explained_variance_ratio_
# Out:
# array([0.3719856 , 0.34700813, 0.17603793])

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** To check what is the total explained variance of the three principal components, I have to sum them together, so it will be 0.89503166, and that is is approximately 0.895, so I can say 89.5% of the total variance in the data is explained by these three principal components.

# %%
# Create a new DataFrame with the PCA data.

pca_df = pd.DataFrame(scaled_pca)

# Copy the crypto names from the original scaled DataFrame

pca_df["coin_id"] = scaled_df.index

# Set the coin_id column as index

pca_df.set_index('coin_id', inplace=True)

# Display the scaled PCA DataFrame

pca_df.head()
# Out:
#                      0         1         2
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Scaled PCA DataFrame

# %%
# Create a list with the number of k-values from 1 to 11

k_val = list(range(1,11))

# %%
# Create an empty list to store the inertia values

inertia= []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_pca`
# 3. Append the model.inertia_ to the inertia list

for k in k_val:
    model_k = KMeans(n_clusters=k, random_state=1)
    model_k.fit(pca_df)
    inertia.append(model_k.inertia_)
inertia
# Out:
# [256.8740855678926,
#  182.3395300777565,
#  135.44240762454214,
#  49.66549665179738,
#  38.67258217591797,
#  34.50757653758154,
#  23.72836478127477,
#  18.5745234401832,
#  15.57267221043334,
#  11.407666572096915]

# %%
# Create a dictionary with the data to plot the Elbow curve

elbow_di = {
    "k" : k_val,
    "inertia": inertia
}

# Create a DataFrame with the data to plot the Elbow curve

elbow_df = pd.DataFrame(elbow_di)
elbow_df.head()
# Out:
#    k     inertia
# 0  1  256.874086
# 1  2  182.339530
# 2  3  135.442408
# 3  4   49.665497
# 4  5   38.672582

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.

elbow_df.hvplot.line(
x = "k",
y = "inertia")
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** The best value for `k` is 4.
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** No. It's showing the same value.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Scaled PCA DataFrame

# %%
# Initialize the K-Means model using the best value for k

pck_model = KMeans(n_clusters=4, random_state=1)

# %%
# Fit the K-Means model using the PCA data
pck_model.fit(pca_df)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled PCA DataFrame

predict2 = pck_model.predict(pca_df)

# Print the resulting array of cluster values.
predict2
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 3, 2, 0, 0, 1, 0, 0, 0, 0],
#       dtype=int32)

# %%
# Create a copy of the scaled PCA DataFrame

scaled_pca_df = pca_df.copy()

# Add a new column to the copy of the PCA DataFrame with the predicted clusters

scaled_pca_df["predicted clusters"] = predict2

# Display the copy of the scaled PCA DataFrame

scaled_pca_df.head()
# Out:
#                      0         1         2  predicted clusters
# coin_id
# bitcoin      -0.600667  0.842760  0.461595                   2
# ethereum     -0.458261  0.458466  0.952877                   2
# tether       -0.433070 -0.168126 -0.641752                   0
# ripple       -0.471835 -0.222660 -0.479053                   0
# bitcoin-cash -1.157800  2.041209  1.859715                   2

# %%
scaled_pca_df.columns
# Out:
# Index([0, 1, 2, 'predicted clusters'], dtype='object')

# %%
scaled_pca_df.columns = scaled_pca_df.columns.astype(str)

# %%
scaled_pca_df.rename(columns = {
    "0" : "PC1",
    "1" : "PC2",
    "2" : "PC3"}, inplace=True)
scaled_pca_df.head()
# Out:
#                    PC1       PC2       PC3  predicted clusters
# coin_id
# bitcoin      -0.600667  0.842760  0.461595                   2
# ethereum     -0.458261  0.458466  0.952877                   2
# tether       -0.433070 -0.168126 -0.641752                   0
# ripple       -0.471835 -0.222660 -0.479053                   0
# bitcoin-cash -1.157800  2.041209  1.859715                   2

# %%
# Create a scatter plot using hvPlot by setting
# `x="PC1"` and `y="PC2"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.

scaled_pca_df.hvplot.scatter(
    x = "PC1",
    y = "PC2",
    by = "predicted clusters",
    title = "PCA Clustering of Cryptocurrencies",
    hover_cols="coin_id",
    xlabel = "PC1 (Principal Component 1)",
    ylabel="PC2 (Principal Component 2)")
# Out:
# :NdOverlay   [predicted clusters]
#    :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Composite plot to contrast the Elbow curves
# YOUR CODE HERE!

# Elbow original datas from scaled_df: 

elbow_df_original = pd.DataFrame({
    "k": k,
    "inertia": iner_list
})

# Elbow PCA datas from scaled_pca_df:

elbow_df_pca = pd.DataFrame({
    "k": k_val,
    "inertia": inertia
})

# Elbow curve original datas:

elbow_curve_original = elbow_df_original.hvplot.line(
    x="k",
    y="inertia",
    title="Elbow curve original datas",
    xlabel="Number of Clusters (k)",
    ylabel="Inertia",
    color="blue"
)

# Elbow curve PCA datas:

elbow_curve_pca = elbow_df_pca.hvplot.line(
    x="k",
    y="inertia",
    title="Elbow curve PCA datas",
    xlabel="Number of Clusters (k)",
    ylabel="Inertia",
    color="red"
)

# Combine 2 plots in one:

elbow_curve_composite = elbow_curve_original * elbow_curve_pca
elbow_curve_composite
# Out:
# :Overlay
#    .Curve.I  :Curve   [k]   (inertia)
#    .Curve.II :Curve   [k]   (inertia)

# %%
# Composite plot to contrast the clusters
# YOUR CODE HERE!

# Scatter original:

scatter_original = scaled_df_2.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by="clusters", 
    hover_cols="coin_id",
    title="Clusters on original datas",
    xlabel="Price change 24h (%)",
    ylabel="Price change 7d (%)"
)

# Scatter plot PCA datas:

scatter_pca = scaled_pca_df.hvplot.scatter(
    x="PC1", 
    y="PC2",
    by="predicted clusters",
    hover_cols="coin_id",
    title="Clusters on PCA datas",
    xlabel="PC1 (Principal Component 1)",
    ylabel="PC2 (Principal Component 2)"
)

# Combine 2 scatters: 

scatter_composite = scatter_original * scatter_pca
scatter_composite
# Out:
# :Overlay
#    .NdOverlay.I  :NdOverlay   [clusters]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [predicted clusters]
#       :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** After visually analyzing the cluster analysis results, it appears that using fewer or more features does not significantly impact the clustering outcome, as both approaches show similar patterns in the plot. However, using fewer features makes it easier to interpret the plot and the data.
